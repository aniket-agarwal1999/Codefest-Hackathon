# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
train_dataset = pd.read_csv('train.csv')
test_dataset = pd.read_csv('test.csv')

# %%
X = train_dataset.iloc[:, [1,2,3,5]].values
y = train_dataset.iloc[:, 6].values

#Encoding the category of the questions column
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
labelencoder = LabelEncoder()
X[:, 0] = labelencoder.fit_transform(X[:, 0])
onehotencoder = OneHotEncoder(categorical_features=[0])
X = onehotencoder.fit_transform(X).toarray()

#So as to remove the dependant variable paradox
X = X[:, 1:]

from sklearn.cross_validation import train_test_split
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size = 0.25, random_state = 0)

y_train = y_train.reshape(y_train.shape[0], 1)
y_valid = y_valid.reshape(y_valid.shape[0], 1)   #These two statements are just so as to convert them into arrays
# Out:
# /usr/local/lib/python3.5/dist-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_valid = sc.transform(X_valid)

# %%
train_dataset.head()
# Out:
#        ID Tag  Reputation  Answers  Username    Views  Upvotes
# 0   52664   a      3942.0      2.0    155623   7855.0     42.0
# 1  327662   a     26046.0     12.0     21781  55801.0   1175.0
# 2  468453   c      1358.0      4.0     56177   8067.0     60.0
# 3   96996   a       264.0      3.0    168793  27064.0      9.0
# 4  131465   c      4271.0      4.0    112223  13986.0     83.0

# %%
plt.scatter(train_dataset['Reputation'], train_dataset['Upvotes'])
plt.xlabel('Reputation')
plt.ylabel('Upvotes')
# Out:
# Text(0,0.5,'Upvotes')

# %%
plt.scatter(train_dataset['Answers'], train_dataset['Upvotes'])
plt.xlabel('Answers')
plt.ylabel('Upvotes')
# Out:
# Text(0,0.5,'Upvotes')

# %%
plt.scatter(train_dataset['Views'], train_dataset['Upvotes'])
plt.xlabel('Views')
plt.ylabel('Upvotes')
# Out:
# Text(0,0.5,'Upvotes')

# %%
A = train_dataset[train_dataset['Tag'] == 'a']
R = train_dataset[train_dataset['Tag'] == 'r']
C = train_dataset[train_dataset['Tag'] == 'c']
J = train_dataset[train_dataset['Tag'] == 'j']
H = train_dataset[train_dataset['Tag'] == 'h']
P = train_dataset[train_dataset['Tag'] == 'p']
X = train_dataset[train_dataset['Tag'] == 'x']
O = train_dataset[train_dataset['Tag'] == 'o']
S = train_dataset[train_dataset['Tag'] == 's']
I = train_dataset[train_dataset['Tag'] == 'i']

plt.scatter(A['Tag'], A['Upvotes'])
plt.scatter(R['Tag'], R['Upvotes'])
plt.scatter(C['Tag'], C['Upvotes'])
plt.scatter(J['Tag'], J['Upvotes'])
plt.scatter(H['Tag'], H['Upvotes'])
plt.scatter(P['Tag'], P['Upvotes'])
plt.scatter(X['Tag'], X['Upvotes'])
plt.scatter(O['Tag'], O['Upvotes'])
plt.scatter(S['Tag'], S['Upvotes'])
plt.scatter(I['Tag'], I['Upvotes'])

plt.xlabel('Tags')
plt.ylabel('Upvotes')
# Out:
# Text(0,0.5,'Upvotes')

# %%
X = train_dataset[train_dataset['Tag'] == 'j']

plt.scatter(X['Views'], X['Upvotes'])
plt.xlabel('Label j Views')
plt.ylabel('Upvotes')
# Out:
# Text(0,0.5,'Upvotes')

# %%
A = train_dataset[train_dataset['Tag'] == 'a']
R = train_dataset[train_dataset['Tag'] == 'r']
C = train_dataset[train_dataset['Tag'] == 'c']
J = train_dataset[train_dataset['Tag'] == 'j']
H = train_dataset[train_dataset['Tag'] == 'h']
P = train_dataset[train_dataset['Tag'] == 'p']
X = train_dataset[train_dataset['Tag'] == 'x']
O = train_dataset[train_dataset['Tag'] == 'o']
S = train_dataset[train_dataset['Tag'] == 's']
I = train_dataset[train_dataset['Tag'] == 'i']

plt.scatter(A['Tag'], A['Reputation'])
plt.scatter(R['Tag'], R['Reputation'])
plt.scatter(C['Tag'], C['Reputation'])
plt.scatter(J['Tag'], J['Reputation'])
plt.scatter(H['Tag'], H['Reputation'])
plt.scatter(P['Tag'], P['Reputation'])
plt.scatter(X['Tag'], X['Reputation'])
plt.scatter(O['Tag'], O['Reputation'])
plt.scatter(S['Tag'], S['Reputation'])
plt.scatter(I['Tag'], I['Reputation'])

plt.xlabel('Tags')
plt.ylabel('Reputation')
# Out:
# Text(0,0.5,'Reputation')

# %%
if(test_dataset['Reputation'])
